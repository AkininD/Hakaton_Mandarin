# %%
IIIR

# %% [markdown]
# Хакатоооон!!!

# %% [markdown]
# #EDA Колосов. Список признаков внутрни

# %% [markdown]
# **Признаки остающиеся от первоначальных:**
# * Position - ОБРАБОТАН ВАРВАРСКИМ СПОСОБОМ (Спец.работа, Управление, Предпринимательство, Без должности)
# * 'month_profit',
# * 'month_expense',
# * 'gender',
# * 'family_status',
# * 'child_count',
# * 'SNILS',
# * 'bank_A_decision',
# * 'bank_B_decision',
# * 'bank_C_decision',
# * 'bank_D_decision',
# * 'bank_E_decision',
# * 'merch_code',
# * 'loan_amount',
# * 'loan_term',
# * 'goods_category',
#
# **Новые признаки:**
# * 'age' - Возраст (num)
# * 'age_status' - Статус по возрасту (молодеж, трудоспособный, пенсионер)
# * 'finished_education' - Завершенное образование (bool)
# * 'education_raiting' - Рейтинг образования (bool)
# * 'is_student' - Студент (bool)
# * 'is_pensioner' - Пенсионер (bool)
# * 'is_maternity_leave' - В декретном отпуске (bool)
# * 'is_hired_worker' - Нанятый работник (bool)
# * 'is_not_worker' - Неработающий (bool)
# * 'is_works_full_time' - Работает на полную ставку (bool)
# * 'is_self_employed' - Самозанятый (bool)
# * 'experience_over_10_year' - Опыт более 10 лет (bool)
# * 'last_work_years' - Последние годы работы (num)
# * 'is_position' - Имеет должность (bool)
# * 'salary_to_avg_income_Ratio' - Отношение зарплаты к среднему доходу (num) (среднее из статистики страны)
# * 'age_to_average_marriage_age_ratio' - Отношение возраста к среднему возрасту бракосочетания (num) (среднее из статистики страны)
# * 'is_single_parent' - Мать/отец оидиночка (bool)
# * 'large_family' - Многодетная семья (bool)
# * 'is_married' - В браке (bool)
# * 'was_married' - Был в браке (bool)
# * 'living_with_partner' - Проживает с партнером/супругом (bool)
# * 'family_mrot' - МРОТ по семье (num)
# * 'is_possibly_pays_bills' - Возможно, оплачивает алименты (bool)
# * 'Age/Cancer_Incidence_Ratio' - Отношение к среднему показателю возраста по заболеваемости раком (num)

# %% [markdown]
# ##файл с профессиями

# %%
activity_bins = {
        'релтор': 'Управление',
    'пен': 'Управление',
    'помощник бариста': 'Специализированная работа',
    'мастер по маникюру': 'Специализированная работа',
    'мастер участка': 'Управление',
    'бриг': 'Управление',
    'бухг': 'Управление',
    'врач педиатр': 'Управление',
    'кредитный эксперт': 'Управление',
    'инженер расчета': 'Управление',
    'оператор ооу': 'Специализированная работа',
    'сотрудник транспортной безопасности': 'Управление',
    'специалист по  продажам': 'Управление',
    'терми': 'Специализированная работа',
    'монтажник окон пвх': 'Специализированная работа',
    'администратор / автомойщик': 'Управление',
    'универсальный продавец консультант': 'Специализированная работа',
    'консутльнат': 'Специализированная работа',
    'концертмейстер': 'Управление',
    'руково': 'Управление',
    'разнорабочий (ая)': 'Специализированная работа',
    'горновой доменной печи': 'Специализированная работа',
    'мастер смр': 'Специализированная работа',
    'начальник производства': 'Управление',
    'организатор перевозок': 'Управление',
    'мастер ма': 'Управление',
    'мастер отделачник': 'Специализированная работа',
    'промы': 'Управление',
    'шеф': 'Управление',
    'ассистент категорийного менеджера': 'Управление',
    'кухонный рабочий': 'Специализированная работа',
    'консультант зоны информация': 'Управление',
    'сиделка': 'Специализированная работа',
    'управляющий магазином': 'Управление',
    'отдел партнерских продаж в сфере спорта и медицины': 'Управление',
    'менеджер по отгрузкам': 'Управление',
    'машини': 'Специализированная работа',
    'индивидуальны': 'Управление',
    'штукатур': 'Специализированная работа',
    'нутрициолог': 'Специализированная работа',
    'старший тренер': 'Специализированная работа',
    'инспектор': 'Управление',
    'изготовитель печатных плат': 'Управление',
    'государственный налоговый инспектор': 'Управление',
    'км': 'Управление',
        'специалист поддержки': 'Управление',
    'учи': 'Специализированная работа',
    'специалист по работе с заказчиками': 'Управление',
    'дизай': 'Специализированная работа',
    'бари': 'Специализированная работа',
    'старший бариста': 'Специализированная работа',
    'координатор': 'Управление',
    'художественный руководитель': 'Управление',
    'диспетчер пдса': 'Специализированная работа',
    'уборщик служебных помещений': 'Специализированная работа',
    'начальник отдела продаж': 'Управление',
    'врач-невролог': 'Управление',
    'дояр': 'Специализированная работа',
    'старший тех': 'Управление',
    'гальва': 'Специализированная работа',
    'страховой агент': 'Управление',
    'младший инспектор': 'Управление',
    'машинист насосных установок': 'Специализированная работа',
    'смм менеджер': 'Управление',
    'инженер по охране труда': 'Управление',
    'помощник старшего смены. кондитер': 'Специализированная работа',
    'телемастер': 'Специализированная работа',
    'стрелок санитар': 'Специализированная работа',
    'региональный менеджер. региональный отдел продаж.': 'Управление',
    'уборщик': 'Специализированная работа',
    'управля': 'Управление',
    'медицинский лабораторный техник': 'Управление',
    'врач здравпункта': 'Управление',
    'оператор полуфабрикатов': 'Специализированная работа',
    'управляю': 'Управление',
    'ветери': 'Специализированная работа',
    'мастер строительных работ': 'Управление',
    'эксп': 'Специализированная работа',
    'специа': 'Специализированная работа',
    'командир отделения': 'Управление',
    'научный с': 'Управление',
    'монтер пути': 'Специализированная работа',
    'слесарь-механик': 'Специализированная работа',
    'секретарь учебной части': 'Управление',
    'ведущий специалист сб': 'Управление',
    'старшая акушерка': 'Управление',
    'разработчик автоворонок': 'Управление',
    'руководитель программы «про семью»': 'Управление',
    'бортпровод': 'Специализированная работа',
    'smm специалист': 'Управление',
    'электро': 'Специализированная работа',
        'учас': 'Специализированная работа',
    'библиотекарь': 'Управление',
    'марке': 'Специализированная работа',
    'эл. монтер': 'Специализированная работа',
    'главный врач': 'Управление',
    'мантировщик': 'Специализированная работа',
    'ведущий бу': 'Управление',
    'монт': 'Специализированная работа',
    'директо': 'Управление',
    'менеджер азс': 'Специализированная работа',
    'заместитель начальника': 'Управление',
    'финансовый контроллер': 'Управление',
    'профессор кафедры': 'Управление',
    'тренер групповых программ': 'Специализированная работа',
    'установщик': 'Специализированная работа',
    'корректор': 'Управление',
    'костюмер': 'Специализированная работа',
    'руководител': 'Управление',
    'медицинская санитарка': 'Специализированная работа',
    'специалист по р': 'Специализированная работа',
    'опекун': 'Специализированная работа',
    'геолог': 'Специализированная работа',
    'самелье': 'Специализированная работа',
    'ведущий': 'Управление',
    'бармен': 'Специализированная работа',
    'проджект менеджер': 'Управление',
    'главный спе': 'Специализированная работа',
    'водитель такси': 'Специализированная работа',
    'помошник': 'Специализированная работа',
    'завуч': 'Управление',
    'мед': 'Специализированная работа',
    'разнораб': 'Специализированная работа',
    'вышкомонтажник': 'Специализированная работа',
    'hr-менеджер': 'Управление',
    'учитель-логопед.': 'Управление',
    'админист': 'Управление',
    'персональный ассистент': 'Управление',
    'ассистент мастера приемшика': 'Специализированная работа',
    'режисс': 'Специализированная работа',
    'старший техник-программист': 'Управление',
    'воспита': 'Управление',
    'упаковщик': 'Специализированная работа',
    'младший референт': 'Управление',
    'вед': 'Управление',
    'сот': 'Специализированная работа',
    'продовец': 'Специализированная работа',
        'заведующая складом': 'Специализированная работа',
    'помощник системного администратора': 'Специализированная работа',
    'маршейдер': 'Специализированная работа',
    'медиц': 'Специализированная работа',
    'стропольщик': 'Специализированная работа',
    'учите': 'Управление',
    'прора': 'Специализированная работа',
    'эл. слесарь по ремонту эл. оборудования': 'Специализированная работа',
    'гидромониторщик': 'Специализированная работа',
    'бренд-менеджер': 'Управление',
    'следователь': 'Специализированная работа',
    'педагог дополнительного образования': 'Управление',
    'специалист по работе с семьей': 'Управление',
    'намотч': 'Специализированная работа',
    'ведущий технолог': 'Управление',
    'диспет': 'Специализированная работа',
    'мастер ман': 'Специализированная работа',
    'кондуктор': 'Специализированная работа',
    'полицей': 'Специализированная работа',
    'операто': 'Специализированная работа',
    'оператор машинного доения': 'Специализированная работа',
    'специалист банковского дела': 'Управление',
    'автослесарь': 'Специализированная работа',
    'specialist': 'Специализированная работа',
    'домработница': 'Специализированная работа',
    'водитель штабелера': 'Специализированная работа',
    'администрато': 'Управление',
    'метеоролог': 'Специализированная работа',
    'универсал': 'Специализированная работа',
    'самоазанятый': 'Специализированная работа',
    'офиц': 'Специализированная работа',
    'помо': 'Специализированная работа',
    'пескоструйщик': 'Специализированная работа',
    'косм': 'Специализированная работа',
    'старший кассир': 'Специализированная работа',
    'столяр': 'Специализированная работа',
    'предпри': 'Специализированная работа',
    'штурман': 'Специализированная работа',
    'приемщик': 'Специализированная работа',
    'пре': 'Специализированная работа',
    'специалист по работе с партнерами': 'Управление',
    'оператор 1с': 'Специализированная работа',
    'мастер депиляции': 'Специализированная работа',
    'шеф-повар': 'Специализированная работа',
    'заместитель директора ресторана': 'Управление',
    'кадастровый инженер': 'Специализированная работа',

        'отделочник': 'Специализированная работа',
    'инженер-метролог': 'Специализированная работа',
    'оператор-животновод': 'Специализированная работа',
    'фарм': 'Специализированная работа',
    'инже': 'Специализированная работа',
    'убор': 'Специализированная работа',
    'учитель-логопед': 'Управление',
    'сметчик': 'Специализированная работа',
    'мерчендайзер': 'Специализированная работа',
    'ведущий юрисконсульт': 'Управление',
    'помогающий специалист': 'Специализированная работа',
    'специалист группы контроля финансов': 'Управление',
    'каменщик': 'Специализированная работа',
    'полномочный представитель президента': 'Управление',
    'ведущий специалист  отдела продаж': 'Управление',
    'повар-универсал': 'Специализированная работа',
    'водитель тягоча': 'Специализированная работа',
    'фриланс': 'Специализированная работа',
    'старший менеджер по закупкам': 'Управление',
    'нала': 'Специализированная работа',
    'электрослесарь подземный': 'Специализированная работа',
    'мерчандайзер': 'Специализированная работа',
    'автомеханик': 'Специализированная работа',
    'старший ме': 'Специализированная работа',
    'руководитель фин отдела': 'Управление',
    'фасовщица': 'Специализированная работа',
    'техник по наладки': 'Специализированная работа',
    'специалист опп': 'Специализированная работа',
    'контралер отк': 'Специализированная работа',
    'старший инструктор': 'Специализированная работа',
    'отдела': 'Управление',
    'специалист службы безопасности': 'Управление',
    'арт-директор': 'Управление',
    'радиотелефонист регулировщик': 'Специализированная работа',
    'старший капитан': 'Специализированная работа',
    'младший инспектор группы надзора отдела безопасности': 'Специализированная работа',
    'инспектор по надзору': 'Специализированная работа',
    'продавец консультан': 'Специализированная работа',
    'клинер': 'Специализированная работа',
    'начальнык отдела': 'Управление',
    'менеджер по работе с ключевыми клиентами': 'Управление',
    'вдминистратор': 'Управление',
    'и.о. заместитель ген. директора по развитию': 'Управление',
    'зам.руководителя': 'Управление',
    'ген дир': 'Управление',
    'слесарь по ремонту оборудования': 'Специализированная работа',
        'сва': 'Специализированная работа',
    'доводчик-притиршик': 'Специализированная работа',
    'мар': 'Специализированная работа',
    'клининг-менеджер': 'Специализированная работа',
    'преподователь': 'Управление',
    'старший мене': 'Специализированная работа',
    'контролер кпп': 'Специализированная работа',
    'начальник группы': 'Управление',
    'сыровар': 'Специализированная работа',
    'электромониер': 'Специализированная работа',
    'помошник директора': 'Управление',
    'касс': 'Специализированная работа',
    'эмолировщик': 'Специализированная работа',
    'помошник машиниста': 'Специализированная работа',
    'элек': 'Специализированная работа',
    'смотр': 'Специализированная работа',
    'судебный пристав': 'Специализированная работа',
    'менеджер интернет заказов': 'Управление',
    'помощник маши': 'Специализированная работа',
    'инженер-гидротехник': 'Специализированная работа',
    'проходчик': 'Специализированная работа',
    'директор по безопасности': 'Управление',
    'ведущий инже': 'Специализированная работа',
    'машинист экскаватора': 'Специализированная работа',
    'сценарист': 'Специализированная работа',
    'персональный': 'Специализированная работа',
    'ведущий специалист отдела продаж': 'Управление',
    'оператрр': 'Специализированная работа',
    'оператор аппа': 'Специализированная работа',
    'водитель самосвала': 'Специализированная работа',
    'закро': 'Специализированная работа',
    'мастер по депиляции': 'Специализированная работа',
    'днелопроизводитель': 'Специализированная работа',
    'эл.слесарь по ремонту и обслуживанию распределительных устройств': 'Специализированная работа',
    'нача': 'Специализированная работа',
    'газорезчик / газосварщик': 'Специализированная работа',
    'кла': 'Специализированная работа',
    'соесарь 4 разряда': 'Специализированная работа',
    'кассир-контроллер': 'Специализированная работа',
    'флорист': 'Специализированная работа',
    'составитель поездов': 'Специализированная работа',
    'оператор связи': 'Специализированная работа',
    'осмоторщик ремонтник вагонов': 'Специализированная работа',
    'преподаватель иностранных языков': 'Управление',
    'начальник службы системной интеграции': 'Управление',
    'специалист 2-й категории': 'Специализированная работа',

     'кассир-контролер': 'Специализированная работа',
    'системный инженер': 'Специализированная работа',
    'инс': 'Специализированная работа',
    'аген': 'Специализированная работа',
    'менеджер по недвижимости': 'Управление',
    'продовец консультант': 'Специализированная работа',
    'сторож': 'Специализированная работа',
    'уборщик(ца)': 'Специализированная работа',
    'главный бух': 'Специализированная работа',
    'гардеробщик': 'Специализированная работа',
    'педагог до': 'Управление',
    'слесарь мср': 'Специализированная работа',
    'директор программы развития': 'Управление',
    'рукводитель': 'Управление',
    'руководитель разработки': 'Управление',
    'руководитель группы': 'Управление',
    'регистратор': 'Специализированная работа',
    'артист (ка)': 'Специализированная работа',
    'специалист по кадрам': 'Специализированная работа',
    'начальник военно учетного стола': 'Специализированная работа',
    'водитель охраник': 'Специализированная работа',
    'доверенный врач': 'Специализированная работа',
    'маши': 'Специализированная работа',
    'индиви': 'Специализированная работа',
    'мен': 'Специализированная работа',
    'провод': 'Специализированная работа',
    'установщик оборудования': 'Специализированная работа',
    'управляющий персоналом': 'Управление',
    'главный библиотекарь': 'Специализированная работа',
    'рабочий на кромкооблицовачном станке': 'Специализированная работа',
    'помошник повара': 'Специализированная работа',
    'специалист по аудиту': 'Специализированная работа',
    'машинист крана': 'Специализированная работа',
    'охр': 'Специализированная работа',
    'помощник маш': 'Специализированная работа',
    'тока': 'Специализированная работа',
    'специолист': 'Специализированная работа',
    'проектный менеджер': 'Управление',
    'консу': 'Специализированная работа',
    'ведущий э': 'Специализированная работа',
    'менеджер проекта лента регионы': 'Управление',
    'дежурная': 'Специализированная работа',
    'индивидуальный пре': 'Специализированная работа',
    'врач анестезио́лог-реанимато́лог': 'Специализированная работа',
    'старший смены': 'Специализированная работа',
    'инженер по сопровождению программного обеспечения': 'Специализированная работа',
        'работник отдела кадров': 'Специализированная работа',
    'старший инс': 'Специализированная работа',
    'прокатчик': 'Специализированная работа',
    'бар': 'Специализированная работа',
    'культорганизатор': 'Специализированная работа',
    'менеджер департамента': 'Управление',
    'ведущий экономист': 'Специализированная работа',
    'пред': 'Специализированная работа',
    'управляющий делами': 'Управление',
    'бухгалтер 2 категории': 'Специализированная работа',
    'снабже': 'Специализированная работа',
    'провизор': 'Специализированная работа',
    'старший мен': 'Специализированная работа',
    'медицинский психолог': 'Специализированная работа',
    'управ': 'Управление',
    'полице': 'Специализированная работа',
    'специалист по': 'Специализированная работа',
    'помощник повара': 'Специализированная работа',
    'менеджер по продажам it услуг': 'Управление',
    'смм': 'Специализированная работа',
    'регулировщик': 'Специализированная работа',
    'оператор технической поддержки': 'Специализированная работа',
    'лешмейкер': 'Специализированная работа',
    'инжене': 'Специализированная работа',
    'таргетолог': 'Специализированная работа',
    'фасовщик': 'Специализированная работа',
    'мастер производственного обучения вождению': 'Специализированная работа',
    'генераль': 'Управление',
    'специалст': 'Специализированная работа',
    'экспедитор': 'Специализированная работа',
    'медсестра-анестезист': 'Специализированная работа',
    'подсобный рабочий': 'Специализированная работа',
    'индивидуальный': 'Специализированная работа',
    'аппа': 'Специализированная работа',
    'акт': 'Специализированная работа',
    'мастер по наращиванию ресниц': 'Специализированная работа',
    'мед сестра': 'Специализированная работа',
    'админ': 'Специализированная работа',
    'тату мастер': 'Специализированная работа',
    'сборщик стеклопакетов': 'Специализированная работа',
    'меха': 'Специализированная работа',
    'тракторист': 'Специализированная работа',
    'машинист тепловоза': 'Специализированная работа',
    'кладов': 'Специализированная работа',
    'подсобный работник.': 'Специализированная работа',
    'юридический консультант': 'Специализированная работа',
    'индивидуальный предприниматель': 'Специализированная работа',
    'руководитель': 'Управление',
    'менеджер': 'Управление',
    'заместитель директора': 'Управление',
    'генеральный директор': 'Управление',
    'администратор': 'Специализированная работа',
    'преподаватель': 'Специализированная работа',
    'специалист': 'Специализированная работа',
    'бухгалтер': 'Специализированная работа',
    'водитель реализатор': 'Специализированная работа',
    'помощница': 'Специализированная работа',
    'ведущий инж': 'Специализированная работа',
    'визажист': 'Специализированная работа',
    'продавец-универсал': 'Специализированная работа',
    'хор': 'Специализированная работа',
    'младший сотрудник': 'Специализированная работа',
    'сто': 'Специализированная работа',
    'полицейский': 'Специализированная работа',
    'старший продавец-консультант': 'Специализированная работа',
    'эксперт по рекламе': 'Специализированная работа',
    'директор ф': 'Управление',
    'фото': 'Специализированная работа',
    'управляющ': 'Управление',
    'менеджер-продавец': 'Управление',
    'начальник центра': 'Управление',
    'менедже': 'Управление',
    'секре': 'Специализированная работа',
    'инди': 'Специализированная работа',
    'главный мех': 'Специализированная работа',
    'ассистент': 'Специализированная работа',
    'шве': 'Специализированная работа',
    'промышл': 'Специализированная работа',
    'ген директор': 'Управление',
    'почтальон': 'Специализированная работа',
    'мннеджер': 'Управление',
    'старший специалист группы по работе с вип-клиентами': 'Специализированная работа',
    'волонтер': 'Специализированная работа',
    'оператор станка / машин и оборудования': 'Специализированная работа',
    'специалист по охране труда': 'Специализированная работа',
    'специалист отдела продаж': 'Специализированная работа',
    'санитар(ка)': 'Специализированная работа',
    'лаборант': 'Специализированная работа',
    'казначей': 'Специализированная работа',
    'старший бренд менеджер': 'Управление',
    'мастер бровист': 'Специализированная работа',
    'мастер м': 'Специализированная работа',

        'мастер-техник': 'Специализированная работа',
    'стано': 'Специализированная работа',
    'риелтор': 'Специализированная работа',
    'рядовой': 'Специализированная работа',
    'начальник станции': 'Управление',
    'командир взвода': 'Управление',
    'таксис': 'Специализированная работа',
    'авиадиспетчер': 'Специализированная работа',
    'грузчик': 'Специализированная работа',
    'разработчик': 'Специализированная работа',
    'исполнительный директор': 'Управление',
    'руководитель направления': 'Управление',
    'слесарь подвижного состава': 'Специализированная работа',
    'слесарь по обслуживанию и ремонту подвижного состава': 'Специализированная работа',
    'продюссер': 'Специализированная работа',
    'слесар': 'Специализированная работа',
    'офис-менеджер': 'Управление',
    'специалист по работе с клиентами': 'Специализированная работа',
    'мэнеджер': 'Управление',
    'индив': 'Специализированная работа',
    'менеджер проектов': 'Управление',
    'старший оп': 'Специализированная работа',
    'командир': 'Управление',
    'охра': 'Специализированная работа',
    'делопроизводитель': 'Специализированная работа',
    'препода': 'Специализированная работа',
    'независимый партнер': 'Специализированная работа',
    'начальник п': 'Управление',
    'электрогазосварщик': 'Специализированная работа',
    'социальный педагог': 'Специализированная работа',
    'офици': 'Специализированная работа',
    'старший инжинер по разработке': 'Специализированная работа',
    'приемщик-сдатчик пищевой продукции и полуфабрикатов': 'Специализированная работа',
    'тестировщик': 'Специализированная работа',
    'худ': 'Специализированная работа',
    'заместитель главного бухгалтера': 'Управление',
    'сборщик мебели -грузчик': 'Специализированная работа',
    'финансовый директор': 'Управление',
    'вос': 'Управление',
    'врач косметолог': 'Специализированная работа',
    'менеджер оптовой торговли': 'Управление',
    'животновод': 'Специализированная работа',
    'самозантая': 'Специализированная работа',
    'заместитель': 'Управление',
    'управляющий отделением': 'Управление',
    'телеф': 'Специализированная работа',
        'эксперт в сфере образования': 'Специализированная работа',
    'самозянатая': 'Специализированная работа',
    'санитар': 'Специализированная работа',
    'производитель работ/ прораб': 'Специализированная работа',
    'монтажник тт': 'Специализированная работа',
    'опера': 'Специализированная работа',
    'мастер по ремонту бытовой техники': 'Специализированная работа',
    'моторист': 'Специализированная работа',
    'директрор': 'Управление',
    'руководитель проектов': 'Управление',
    'ведущий бухгалтер': 'Специализированная работа',
    'певчий хора': 'Специализированная работа',
    'инженер пто': 'Специализированная работа',
    'начальник отдела службы безопасности': 'Управление',
    'инженер-сметчик 2 категории': 'Специализированная работа',
    'менеджер по подобору персонала': 'Управление',
    'hr': 'Специализированная работа',
    'прораб': 'Специализированная работа',
    'фитнес-тренер': 'Специализированная работа',
    'электромастер': 'Специализированная работа',
    'газоэлектросварщик': 'Специализированная работа',
    'шиномонтажник': 'Специализированная работа',
    'менеджер - дизайнер': 'Специализированная работа',
    'машинист(ка)': 'Специализированная работа',
    'коммерческий представитель': 'Управление',
    'бьюти мастер': 'Специализированная работа',
    'педагог': 'Специализированная работа',
    'заместитель руководителя': 'Управление',
    'контралер': 'Специализированная работа',
    'парикмахер-стилист': 'Специализированная работа',
    'риэ': 'Управление',
    'главный специалист отдела сопровождения сделок с недвижимостью': 'Специализированная работа',
    'солист военного оркестра': 'Специализированная работа',
    'изолировщик': 'Специализированная работа',
    'монтажник технологических трубопроводов': 'Специализированная работа',
    'представитель': 'Управление',
    'астролог': 'Специализированная работа',
    'водитель эвакуатора': 'Специализированная работа',
    'мал': 'Специализированная работа',
    'пова': 'Специализированная работа',
    'помощник руководителя': 'Управление',
    'заместитель/ и.о. главного бухгалтера': 'Управление',
    'заместитель ру': 'Управление',
    'старший медицинский представитель': 'Специализированная работа',
    'учит': 'Специализированная работа',
    'грумер': 'Специализированная работа',
        'электромонтажник': 'Специализированная работа',
    'помощник ма': 'Специализированная работа',
    'пари': 'Специализированная работа',
    'электросварщик': 'Специализированная работа',
    'косметолог - эстетист': 'Специализированная работа',
    'кровельщик': 'Специализированная работа',
    'начальник отд': 'Управление',
    'менеджер по подбору персонала': 'Управление',
    'фрилансер': 'Специализированная работа',
    'управляющи': 'Управление',
    'инженер-диагност': 'Специализированная работа',
    'главный devops инженер': 'Специализированная работа',
    'методист': 'Специализированная работа',
    'мастер художественной татуировки': 'Специализированная работа',
    'прог': 'Специализированная работа',
    'работник': 'Специализированная работа',
    'художник театрального костюма': 'Специализированная работа',
    'адми': 'Специализированная работа',
    'производитель': 'Специализированная работа',
    'наладчик оборудования': 'Специализированная работа',
    'соучредитель': 'Предпринимательство',
    'предста': 'Специализированная работа',
    'оператор котельных установок': 'Специализированная работа',
    'обрубщик': 'Специализированная работа',
    'воспи': 'Управление',
    'фармацевт': 'Специализированная работа',
    'транспортировщик': 'Специализированная работа',
    'президент': 'Управление',
    'главный спец': 'Специализированная работа',
    'заместитель генерального директора': 'Управление',
    'преподаватель математики': 'Специализированная работа',
    'агент по недвижимости': 'Специализированная работа',
    'старший спе': 'Специализированная работа',
    'контент-менеджер': 'Специализированная работа',
    'контролер': 'Специализированная работа',
    'бариста': 'Специализированная работа',
    'электроник /электронщик': 'Специализированная работа',
    'подолог': 'Специализированная работа',
    'сушильщик': 'Специализированная работа',
    'механ': 'Специализированная работа',
    'менеджер зала': 'Управление',
    'арт-менеджер': 'Специализированная работа',
    'аниматор': 'Специализированная работа',
    'водитель автобуса': 'Специализированная работа',
    'моряк': 'Специализированная работа',
    'старший психолог': 'Специализированная работа',

    'инд': 'индивидуальный предприниматель',
    'ип': 'индивидуальный предприниматель',
    'мене': 'менеджер',
    'адм': 'администратор',
    'препо': 'преподаватель',
    'руков': 'руководитель',
    'руко': 'руководитель',
    'рук': 'руководитель',
    'спец': 'специалист',
    'гене': 'генеральный директор',
    'зам': 'заместитель директора',
    'бух': 'бухгалтер',
    'менед': 'менеджер',
    'инж': 'Специализированная работа',
    'ген': 'Специализированная работа',
    'офи': 'Специализированная работа',
    'генер': 'Специализированная работа',
    'генеральный': 'Управление',
    'маст': 'Специализированная работа',
    'сле': 'Специализированная работа',
    'водит': 'Специализированная работа',
    'свар': 'Специализированная работа',
    'дир': 'Управление',
    'генера': 'Специализированная работа',
    'специ': 'Специализированная работа',
    'прода': 'Специализированная работа',
    'воспит': 'Специализированная работа',
    'админи': 'Специализированная работа',

    'менеджер': 'Управление',
    'индивидуальный предприниматель': 'Предпринимательство',
    'самозанятая': 'Предпринимательство',
    'руководитель': 'Управление',
    'специалист': 'Специализированная работа',
    'директор': 'Управление',
    'старший специалист': 'Специализированная работа',
    'администратор': 'Специализированная работа',
    'самозанятый': 'Предпринимательство',
    'генеральный директор': 'Управление',
    'бухгалтер': 'Специализированная работа',
    'нет должности': 'Без должности',
    'заместитель директора': 'Управление',
    'водитель': 'Специализированная работа',
    'маркетолог': 'Специализированная работа',
    'продавец': 'Специализированная работа',
    'оператор': 'Специализированная работа',
    'преподаватель': 'Специализированная работа',
    'управляющий': 'Управление',
    'повар': 'Специализированная работа',
    'юрист': 'Специализированная работа',
    'старший менеджер': 'Управление',
    'ведущий менеджер': 'Управление',
    'консультант': 'Специализированная работа',
    'менеджер по продажам': 'Управление',
    'официант': 'Специализированная работа',
    'главный бухгалтер': 'Специализированная работа',
    'учредитель': 'Предпринимательство',
    'мастер': 'Специализированная работа',
    'курьер': 'Специализированная работа',
    'начальник отдела': 'Управление',
    'кладовщик': 'Специализированная работа',
    'учитель': 'Специализированная работа',
    'инженер': 'Специализированная работа',
    'монтажник': 'Специализированная работа',
    'косметолог': 'Специализированная работа',
    'продавец-консультант': 'Специализированная работа',
    'директор филиала/ департамента': 'Управление',
    'врач': 'Специализированная работа',
    'специалист по продажам': 'Специализированная работа',
    'программист': 'Специализированная работа',
    'сотрудник охраны': 'Специализированная работа',
    'слесарь': 'Специализированная работа',
    'ведущий специалист': 'Специализированная работа',
    'главный специалист': 'Специализированная работа',
    'кассир': 'Специализированная работа',
    'товаровед': 'Специализированная работа',
    'массажист': 'Специализированная работа',
    'главный менеджер': 'Управление',
    'электромонтер': 'Специализированная работа',
    'мастер маникюра': 'Специализированная работа',
    'старший спец': 'Специализированная работа',
    'графический дизайнер': 'Специализированная работа',
    'менеджер по работе с маркетплейсами': 'Управление',
    'репетитор': 'Специализированная работа',
    'технолог': 'Специализированная работа',
    'электрик': 'Специализированная работа',
    'продавец-кассир': 'Специализированная работа',
    'руководитель колл-центра': 'Управление',
    'продюсер': 'Управление',
    'экономист': 'Специализированная работа',
    'руководитель отдела': 'Управление',
    'менеджер по закупкам': 'Управление',
    'начальник участка': 'Управление',
    'механик': 'Специализированная работа',
    'торговый представитель': 'Специализированная работа',
    'старший продавец': 'Специализированная работа',
    'заведующий складом': 'Управление',
    'менеджер по закупке': 'Управление',
    'руководитель отдела продаж': 'Управление',
    'директор магазина': 'Управление',
    'председатель': 'Управление',
    'машинист': 'Специализированная работа',
    'супервайзер': 'Управление',
    'персональный менеджер': 'Управление',
    'коммерческий директор': 'Управление',
    'инструктор': 'Специализированная работа',
    'оператор склада': 'Специализированная работа',
    'сварщик': 'Специализированная работа',
    'продавец кассир': 'Специализированная работа',
    'водитель-экспедитор': 'Специализированная работа',
    'старший слесарь': 'Специализированная работа',
    'хормейстер': 'Специализированная работа',
    'адвокат': 'Специализированная работа',
    'диспетчер': 'Специализированная работа',
    'ведущий инженер': 'Специализированная работа',
    'агент': 'Специализированная работа',
    'рабочий': 'Специализированная работа',
    'медицинская сестра': 'Специализированная работа',
    'помощник юриста': 'Специализированная работа',
    'токарь': 'Специализированная работа',
    'владелец': 'Предпринимательство',
    'начальник': 'Управление',
    'тренер': 'Специализированная работа',
    'психолог-консультант': 'Специализированная работа',
    'логопед': 'Специализированная работа',
    'дизайнер': 'Специализированная работа',
    'психолог': 'Специализированная работа',
    'управляющая': 'Управление',
    'региональный менеджер': 'Управление',
    'менеджер торговой зоны': 'Управление',
    'парикмахер': 'Специализированная работа',
    'сборщик изделий из стеклопластиков в': 'Специализированная работа',
    'аналитик': 'Специализированная работа',
    'финансовый консультант': 'Специализированная работа',
    'командир отдедения': 'Управление',
    'главный инженер': 'Управление',
    'эксперт': 'Специализированная работа',
    'заместитель / и.о. генерального директора': 'Управление',
    'доцент': 'Специализированная работа',
    'воспитатель': 'Специализированная работа',
    'старший менедж': 'Управление',
    'швея': 'Специализированная работа',
    'системный администратор': 'Специализированная работа',
    'формовщик': 'Специализированная работа',
    'ведущий спе': 'Специализированная работа',
    'заведующая отделением': 'Управление',
    'средний медперсонал': 'Специализированная работа',
    'охранник': 'Специализированная работа',
    'старший кладовщик': 'Специализированная работа',
    'руководитель колл центра': 'Управление',
    'инженер-технолог': 'Специализированная работа',
    'техник': 'Специализированная работа',
    'лаборант химического анализа': 'Специализированная работа',
    'старший оператор': 'Специализированная работа',
    'косметолог-визажист': 'Специализированная работа',
    'медсестра': 'Специализированная работа',
        'оператор колл-центра': 'Специализированная работа',
    'техперсонал': 'Специализированная работа',
    'директор по развитию': 'Управление',
    'няня': 'Специализированная работа',
    'сотрудник': 'Специализированная работа',
    'старший сотрудник охраны': 'Специализированная работа',
    'заме': 'Управление',
    'автоэлектрик': 'Специализированная работа',
    'оптометрист': 'Специализированная работа',
    'монтажник/монтер': 'Специализированная работа',
    'режиссер': 'Специализированная работа',
    'руководитель департамента': 'Управление',
    'разнорабочий': 'Специализированная работа',
    'кондитер': 'Специализированная работа',
    'фельдшер': 'Специализированная работа',
    'логист': 'Специализированная работа',
    'врач-стоматолог': 'Специализированная работа',
    'клад': 'Специализированная работа',
    'продавец консультант': 'Специализированная работа',
    'наставник': 'Специализированная работа',
    'заместитель завелующего': 'Управление',
    'старший администратор': 'Специализированная работа',
    'старший специалист связи': 'Специализированная работа',
    'представитель банка': 'Специализированная работа',
    'руководитель отдела маркетинга': 'Управление',
    'сотрудник склада': 'Специализированная работа',
    'заведующий': 'Управление',
    'риэлтор': 'Специализированная работа',
    'секретарь': 'Специализированная работа',
    'уборщица': 'Специализированная работа',
    'начальник цеха': 'Управление',
    'помощник': 'Управление',
    'менеджер по поисковой оптимизации и продвижению сайтов': 'Управление',
    'маляр': 'Специализированная работа',
    'ведущий с': 'Специализированная работа',
    'маркето': 'Специализированная работа',
    'начальник смены': 'Управление',
    'менеджер торгового напоавления': 'Управление',
    'фармацевт / провизор': 'Специализированная работа',
    'судебный': 'Специализированная работа',
    'фасилитатор': 'Специализированная работа',
    'пластический хирург': 'Специализированная работа',
    'мастер ногтевого сервиса': 'Специализированная работа',
    'термист': 'Специализированная работа',
    'комплектовщик': 'Специализированная работа',
    'судосборщик': 'Специализированная работа',
        'генеральный дирекор': 'Управление',
    'музыкальный р': 'Специализированная работа',
    'помощник оперативного дежурного': 'Специализированная работа',
    'асистент': 'Специализированная работа',
    'монтер': 'Специализированная работа',
    'менедж': 'Управление',
    'руководитель проекта': 'Управление',
    'smm-менеджер': 'Специализированная работа',
    'турагент': 'Специализированная работа',
    'санитарка': 'Специализированная работа',
    'пекарь': 'Специализированная работа',
    'организатор': 'Управление',
    'бухга': 'Специализированная работа',
    'специалист по охране труда и промышленной безопасности': 'Специализированная работа',
    'управляющий директор по работе с состоятельными клиентами': 'Управление',
    'кадровый работник': 'Специализированная работа',
    'лабораторный техник': 'Специализированная работа',
    'упровляющий директор': 'Управление',
    'юрисконсульт': 'Специализированная работа',
    'продав': 'Специализированная работа',
    'рабочий производственного цеха': 'Специализированная работа',
    'помощник геодезиста': 'Специализированная работа',
    'оценщик': 'Специализированная работа',
    'врач-хирург': 'Специализированная работа',
    'копирайтер': 'Специализированная работа',
    'главный технолог': 'Специализированная работа',
    'разнорабочая': 'Специализированная работа',
    'директор службы': 'Управление',
    'заместитель начальника отдела': 'Управление',
    'сео-менеджер': 'Специализированная работа',
    'вра': 'Специализированная работа',
    'дире': 'Управление',
    'исполнитель': 'Специализированная работа',
    'официа': 'Специализированная работа',
    'мерч': 'Специализированная работа',
    'pr-менеджер': 'Специализированная работа',
    'мастер по обслуживанию абонентов': 'Специализированная работа',
    'заместитель директора по финансам': 'Управление',
    'заведующая производством': 'Управление',
    'старший товаровед': 'Специализированная работа',
    'прод': 'Специализированная работа',
    'заместитель начальника цеха по экономике': 'Управление',
    'фин': 'Специализированная работа',
    'художник': 'Специализированная работа',
    'руководитель обособленного подразделения': 'Управление',
    'менеджер по маркетингу': 'Специализированная работа',
        'водитель экспедитор': 'Специализированная работа',
    'электромеханик': 'Специализированная работа',
    'младший воспитатель': 'Специализированная работа',
    'председатель наблюдательского совета': 'Управление',
    'управл': 'Управление',
    'ветеринар': 'Специализированная работа',
    'дирек': 'Управление',
    'собственник': 'Предпринимательство',
    'помощник-монтажник': 'Специализированная работа',
    'админис': 'Специализированная работа',
    'менеджер колл центра': 'Управление',
    'медбрат': 'Специализированная работа',
    'зам.зав аптекой': 'Управление',
    'сотрудник пункта выдачи': 'Специализированная работа',
    'финансовый советник': 'Специализированная работа',
    'химик-технолог': 'Специализированная работа',
    'инспектор отдела кадров': 'Специализированная работа',
    'главный бу': 'Специализированная работа',
    'тренер / инструктор': 'Специализированная работа',
    'то': 'Специализированная работа',
    'охран': 'Специализированная работа',
    'коуч': 'Специализированная работа',
    'оперативный дежурный': 'Специализированная работа',
    'помощник по уходу': 'Специализированная работа',
    'стар': 'Управление',
    'рекрутер': 'Специализированная работа',
    'младший сотр': 'Специализированная работа',
    'препод': 'Специализированная работа',
    'сотрудник ох': 'Специализированная работа',
    'дежурный менеджер': 'Специализированная работа',
    'директор (исполн./коммерч./финанс./технич.)': 'Управление',
    'бригадир': 'Специализированная работа',
    'груз': 'Специализированная работа',
    'фотограф': 'Специализированная работа',
    'предприниматель': 'Предпринимательство',
    'старший помощник': 'Управление',
    'менеджер пункта выдачи': 'Управление',
    'заместитель директора по учебной работе': 'Управление',
    'работник пищеблока': 'Специализированная работа',
    'смм специалист': 'Специализированная работа',
    'автомастер': 'Специализированная работа',
    'тех': 'Специализированная работа',
    'строитель': 'Специализированная работа',
    'менеджер по работе с клиентами': 'Управление',
    'лесной пожарный': 'Специализированная работа',
    'электромеханик кипиа': 'Специализированная работа'
}

# %% [markdown]
# ## Признаки

# %%
# Возраст заемшика
data['age'] = 2023 - pd.to_datetime(data['BirthDate']).dt.year

# %% [markdown]
# ---

# %%
#Возрастной статус человека
def get_age_status(age, is_female):
    minor_age = 17
    adult_age = 18
    pensioner_age_woman = 65
    pensioner_age_man = 68

    if age <= minor_age:
        age_status = 'несовершеннолетний'
    elif is_female:
        if adult_age <= age < pensioner_age_woman:
            age_status = 'трудоспособный'
        else:
            age_status = 'пенсионер'
    else:
        if adult_age <= age < pensioner_age_man:
            age_status = 'трудоспособный'
        else:
            age_status = 'пенсионер'

    return age_status

# %%
data['age_status'] = data.apply(lambda row: get_age_status(row['age'], row['Gender']), axis=1)

# %% [markdown]
# ---

# %%
# Выделим недоучившихся в отдельную колонку 1 - Оконченное, 0 - Неоконченное
data['finished_education'] = data['education'].apply(lambda x: 0 if 'Неоконченное' in x else 1)

# %%
# Наличие высшего образования 0 - Нет, 1 - Есть
data['education_raiting'] = data['education'].replace({
        "Высшее - специалист": 1,
        "Среднее профессиональное": 0,
        "Среднее": 0,
        "Неоконченное высшее": 1,
        "Бакалавр": 1,
        "Несколько высших": 1,
        "Магистр": 1,
        "Неоконченное среднее": 0,
        "MBA": 1,
        "Ученая степень": 1
        })

# %% [markdown]
# ---

# %%
# Студенты
data['is_student'] = data['employment status'].apply(lambda x: 1 if 'Студент' in x else 0)

# %%
# пенсионеры
data['is_pensioner'] = data['employment status'].apply(lambda x: 1 if 'Пенсионер' in x else 0)

# %%
# в декрете
data['is_maternity_leave'] = data['employment status'].apply(lambda x: 1 if 'Декретный отпуск' in x else 0)

# %%
# Натятый рабочий
data['is_hired_worker'] = data['employment status'].apply(lambda x: 1 if 'Работаю по найму' in x else 0)

# %%
# Тунеядец
data['is_not_worker'] = data['employment status'].apply(lambda x: 1 if 'Не работаю' in x else 0)

# %%
# 0 - не полный рабочий день, 1 - полный рабочий день
data['is_works_full_time'] = data['employment status'].apply(lambda x: 1 if 'полный рабочий день' in x else 0)

# %%
# Самозанятый
data['is_self_employed'] = data['employment status'].apply(lambda x: 1 if 'Собственное дело' in x else 0)

# %% [markdown]
# ---

# %%
data['Value'] = data['Value'].fillna('Не работал')

# %%
# Стаж работы от 10 лет и выше
data['experience_over_10_year'] = data['Value'].apply(lambda x: 1 if '10 и более лет' in x else 0)

# %% [markdown]
# ---

# %%
data['JobStartDate'] = data['JobStartDate'].fillna(0)

# %%
data['last_work_years'] = 2023 - pd.to_datetime(data['JobStartDate']).dt.year

# %% [markdown]
# ---

# %% [markdown]
# В признаке Position имеютсья разныке регистры и пробелы в названии профессиии, а также разные нейминги

# %%
data['Position'] = data['Position'].fillna('нет должности')

# %%
# Переводим в нижний регистр и Удалить лишние пробелы в значениях столбиков
data['Position'] = data['Position'].str.strip().str.lower()

# %%
data['is_position'] = data['Position'].apply(lambda x: 1 if not 'нет должности' in x else 0)

# %% [markdown]
# ---

# %%
data['Position'] = data['Position'].replace(activity_bins)

# %% [markdown]
# ---

# %% [markdown]
# Отшение зп к среднему показателю по стране

# %%
#Отноешние ЗП к среднему доходу https://finance.mail.ru/2023-11-01/golikova-srednyaya-zarplata-v-rossii-vyrosla-do-70-3-tysyachi-rubley-v-2023-godu-58449869/
average_income = 70.3
data['salary_to_avg_income_Ratio'] = data['MonthProfit'] / average_income

# %% [markdown]
# ---

# %%
#Заполняем пропуски по медиане
data['Family status'] = data['Family status'].fillna(data['Family status'].mode()[0])
data['ChildCount'] = data['ChildCount'].fillna(data['ChildCount'].mode()[0])
data['Gender'] = data['Gender'].fillna(data['Gender'].mode()[0])

# %%
# Отношение возроста гражданина к Среднему значению возраста россиян, которые вступают в брак
def get_age_to_average_marriage_age_ratio(gender, age):
  average_men = 25.4
  average_woman = 23.2
  if gender:
    age_to_average_marriage_age_ratio = age / average_woman
  else:
    age_to_average_marriage_age_ratio = age / average_men
  return age_to_average_marriage_age_ratio

# %%
data['age_to_average_marriage_age_ratio'] = data.apply(lambda row: get_age_to_average_marriage_age_ratio(row['Gender'], row['age']), axis=1)

# %%
def get_single_parent(family_status, child_count):
    single_parent_arr = ['Никогда в браке не состоял(а)',
                         'Разведён / Разведена',
                         'Вдовец / вдова']

    return 1 if family_status in single_parent_arr and child_count > 0 else 0

# %%
#Родители одиночки
data['is_single_parent'] = data.apply(lambda row: get_single_parent(row['Family status'], row['ChildCount']), axis=1)

# %% [markdown]
# ---

# %%
#Многодетные семьи
data['large_family'] = data['ChildCount'].apply(lambda x: 1 if x > 2 else 0)

# %% [markdown]
# ---

# %%
# В браке
data['is_married'] = data.apply(lambda row: 1 if row['Family status'] == 'Женат / замужем' else 0, axis=1)

# %%
# Были в браке
# Суды, наследство, кредиты долги
data['was_married'] = data.apply(
    lambda row: 1 if row['Family status'] in ['Разведён / Разведена', 'Вдовец / вдова'] else 0,
    axis=1
    )

# %%
# Живет С/Без Парнера
# Есть кому финансово помочь
data['living_with_partner'] = data.apply(
    lambda row: 1 if row['Family status'] in ['Женат / замужем', 'Гражданский брак / совместное проживание'] else 0,
    axis=1
    )

# %% [markdown]
# ---

# %%
def get_family_mrot(age_status, child_count, is_married):
  child_mrot = 13944
  worked_mrot = 15669
  pensioner_mrot = 12363

  #для женщин
  if age_status == 'трудоспособный':
    family_mrot = worked_mrot + child_count * child_mrot + is_married * worked_mrot
  elif age_status == 'пенсионер':
    family_mrot = pensioner_mrot + child_count * child_mrot + is_married * worked_mrot
  else:
    family_mrot = child_mrot + child_count * child_mrot + is_married * worked_mrot

  return family_mrot

# %% [markdown]
# # Толстых Андрей

# %%
import os
import pickle
import numpy as np

import pandas as pd
from scipy.stats import pearsonr
from sklearn.preprocessing import OrdinalEncoder

from typing import Any, Dict, List, Union

import seaborn as sns
from matplotlib import pylab as plt

# %matplotlib inline
plt.style.use('bmh')

# %%
def dump_or_load_object(path: str, obj: Any = None, force: bool = False) -> Any:
    """Дамп объекта или его загрузка, если он уже был сохранен

    Args:
        path (str): путь до сохранения
        obj (Any, Optional): объект для сохранения
        force (bool): перезаписать объект

    Returns:
        (Any): объект (загруженый или входной)
    """

    folders, filename = os.path.split(path)
    if not os.path.exists(folders):
        os.makedirs(folders, exist_ok=True)
        pickle.dump(obj, open(path, 'wb'))
    elif filename not in os.listdir(folders):
        pickle.dump(obj, open(path, 'wb'))
    else:
        obj = pickle.load(open(path, 'rb'))

    return obj


def calculate_corr_pvalues(data: pd.DataFrame) -> pd.DataFrame:
    """Рассчет p-value для матрицы корреляций

    Args:
        data (pd.DataFrame): датасет/данные

    Returns:
        (pd.DataFrame): p-value для матрицы корреляций
    """
    dfcols = pd.DataFrame(columns=data.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in data.columns:
        for c in data.columns:
            tmp = data[data[r].notnull() & data[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
data = pd.read_csv("./SF_Mandarin_dataset_ver3_csv.csv", sep=";")
data.sample()
# Out:
#       SkillFactory_Id                    BirthDate            education  \
# 2327           3138.0  1995-05-06 00:00:00.0000000  Высшее - специалист
#
#                                employment status      Value  \
# 2327  Работаю по найму полный рабочий день/служу  8 - 9 лет
#
#                      JobStartDate                        Position  \
# 2327  2014-11-01 00:00:00.0000000  оператор технической поддержки
#
#       MonthProfit  MonthExpense  Gender  ... SNILS  BankA_decision  \
# 2327     120000.0       20000.0     0.0  ...   1.0         success
#
#       BankB_decision BankC_decision BankD_decision BankE_decision Merch_code  \
# 2327         success        success         denied         denied        9.0
#
#      Loan_amount  Loan_term  Goods_category
# 2327     57000.0       12.0           Other
#
# [1 rows x 22 columns]

# %%
non_use = ['SkillFactory_Id']
num = [
    'age',
    'last_work_years',
    'MonthProfit',
    'MonthExpense',
    'ChildCount',
    'Loan_term',
    'Loan_amount'
]
cat = [
    'education',
    'employment status',
    'Value',
    'Position',
    'Gender',
    'Family status',
    'SNILS',
    'Goods_category',
    'Merch_code'
]
raw_target = [
    'BankA_decision',
    'BankB_decision',
    'BankC_decision',
    'BankD_decision',
    'BankE_decision'
]
columns_cat = dump_or_load_object(
    "./preprocessors/columns_cat.pkl", {'non_use': non_use, 'num': num, 'cat': cat, 'raw_target': raw_target}
)

# %%
def basic_process(data: pd.DataFrame, columns_cat: Dict[str, List[str]], drop: bool = True) -> pd.DataFrame:
    """Базовые преобразования
            * дата рождения -> возраст (полных лет?)
            * дата новой работы -> время пребывания на последней работе (лет ? 0 - меньше года)
            * одобрение банка -> цифры (denied = 0, success = 1, error = 2)
            * если вся строка nan - drop
            * удаляем id
            * Position - в нижний регистр + удалем пробелы

        Args:
            data (pd.DataFrame): датасет/данные
            columns_cat (str, Dict[List[str]]): сортировка колонок
            drop (bool): удалить исходные колонки? Defaults to False

        Returns:
            (pd.DataFrame): преобразованный датасет/данные
    """

    data['age'] = 2023 - pd.to_datetime(data['BirthDate']).dt.year
    data['last_work_years'] = 2023 - pd.to_datetime(data['JobStartDate']).dt.year
    data['Position'] = data['Position'].str.lower().str.strip()

    for col in columns_cat['raw_target']:
        data[col] = data[col].replace({"denied": 0, "success": 1, "error": 2})

    drop_rows = lambda row: row.isna().sum() == data.shape[1]
    data = data.drop(data[data.apply(drop_rows, axis=1)].index)
    data = data.drop(columns=columns_cat['non_use'])

    if drop:
        data = data.drop(columns=['BirthDate', 'JobStartDate'])
    return data

basic_process = dump_or_load_object("./preprocessors/basic_process.pkl", basic_process)

# %%
data = basic_process(data, columns_cat)

# %%
_corr = data[columns_cat['num'] + columns_cat['raw_target']].corr()
_p_corr = calculate_corr_pvalues(data[columns_cat['num'] + columns_cat['raw_target']])
plt.figure(figsize=(15, 7))
plt.grid(visible=False)
sns.heatmap(_corr, annot=True)
plt.title("Матрица корреляций")
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.grid(visible=False)
sns.heatmap(_p_corr.astype(float), annot=True)
plt.title("Значения p-value для корреляций")
plt.show()

# %%
print("Количество пропусков по столбцам")
data.isna().sum()
# Out:
# Количество пропусков по столбцам
# education              0
# employment status      0
# Value                 80
# Position             109
# MonthProfit            0
# MonthExpense           0
# Gender                37
# Family status         37
# ChildCount            37
# SNILS                  0
# BankA_decision         0
# BankB_decision         0
# BankC_decision         0
# BankD_decision         0
# BankE_decision         0
# Merch_code             0
# Loan_amount            0
# Loan_term              0
# Goods_category         0
# age                    0
# last_work_years      109
# dtype: int64

# %%
print("Максимум (топ-10) пропусков в одной строке")
data.isna().sum(axis=1).sort_values(ascending=False).iloc[:10]
# Out:
# Максимум (топ-10) пропусков в одной строке
# 6013    6
# 6498    6
# 6427    6
# 2219    5
# 544     5
# 5685    5
# 3222    5
# 5615    3
# 6185    3
# 6523    3
# dtype: int64

# %%
data[columns_cat['num']].min(axis=0)
# Out:
# age                  18.0
# last_work_years       0.0
# MonthProfit          50.0
# MonthExpense          0.0
# ChildCount            0.0
# Loan_term             6.0
# Loan_amount        4000.0
# dtype: float64

# %%
def process_nan(data: pd.DataFrame) -> pd.DataFrame:
    """Добавление колоноки с числом пропусков, замена пропусков на -1
    Args:
        data (pd.DataFrame): датасет/данные

    Returns:
        (pd.DataFrame): преобразованный датасет/данные
    """

    return data.fillna(-1)

process_nan = dump_or_load_object("./preprocessors/process_nan.pkl", process_nan)

# %%
data = process_nan(data)
print("Пропусков после обработки: ", data.isna().sum().sum())
# Out:
# Пропусков после обработки:  0

# %%
cat_preprocessor = OrdinalEncoder()
cat_preprocessor.fit(data[columns_cat['cat']].astype(str))
cat_preprocessor = dump_or_load_object("./preprocessors/cat_preprocessor.pkl", cat_preprocessor)

# %%
data[columns_cat['cat']] = cat_preprocessor.transform(data[columns_cat['cat']].astype(str))
data.sample()
# Out:
#       education  employment status  Value  Position  MonthProfit  \
# 4259        2.0                5.0    7.0     250.0     120000.0
#
#       MonthExpense  Gender  Family status  ChildCount  SNILS  ...  \
# 4259       21000.0     1.0            4.0         0.0    0.0  ...
#
#       BankB_decision  BankC_decision  BankD_decision  BankE_decision  \
# 4259             1.0             0.0             1.0             1.0
#
#       Merch_code  Loan_amount  Loan_term  Goods_category   age  \
# 4259        57.0      92000.0       12.0             4.0  25.0
#
#       last_work_years
# 4259              3.0
#
# [1 rows x 21 columns]

# %%
fig, ax = plt.subplots(4, 4, figsize=(15, 18))
for idx, col in enumerate(columns_cat['cat'] + columns_cat['num']):
    ax_idx_1 = idx // 4
    ax_idx_2 = idx % 4
    sns.histplot(data[col], stat = 'probability', ax=ax[ax_idx_1, ax_idx_2])
    ax[ax_idx_1, ax_idx_2].set_title(col)
    ax[ax_idx_1, ax_idx_2].set_xlabel("")
    ax[ax_idx_1, ax_idx_2].set_ylabel("")
    if col in ["MonthExpense", "MonthProfit"]:
        ax[ax_idx_1, ax_idx_2].set_xscale('log')
    if idx % 4 == 0:
        ax[ax_idx_1, ax_idx_2].set_ylabel("Вероятность")
    if idx > 11:
        ax[ax_idx_1, ax_idx_2].set_xlabel("Значение")

# %%
fig, ax = plt.subplots(1, 5, figsize=(15, 5))
for idx, bank in enumerate(columns_cat['raw_target']):
    sns.histplot(data[bank], stat = 'probability', ax=ax[idx])
    if idx > 0:
        ax[idx].set_ylabel("")
plt.show()

# %%
def add_features(data: pd.DataFrame) -> pd.DataFrame:
    """
    Добавление фичей:
        * отношение доход/расход
        * отношение объем кредита/срок кредита
        * отношение (доход - расход) / (объем кредита/срок кредита)

    Args:
        data (pd.DataFrame): данные

    Returns:
        (pd.DataFrame): данные, обогощенные фичами
    """

    data["profit_expense"] = data["MonthProfit"] / data["MonthExpense"]
    data["loan_term_amount"] = data["Loan_amount"] / data["Loan_term"]
    data["month_load"] = (data["MonthProfit"] - data["MonthExpense"]) / (data["Loan_amount"] / data["Loan_term"])

    # проверям на бесконечность
    data[data["profit_expense"] == np.inf] = -1
    data[data["loan_term_amount"] == np.inf] = -1
    data[data["month_load"] == np.inf] = -1
    return data

add_features = dump_or_load_object("./preprocessors/add_features.pkl", add_features)

# %%
data = add_features(data)
columns_cat['num'] += ["profit_expense", "loan_term_amount", "month_load"]
columns_cat = dump_or_load_object("./preprocessors/post_columns_cat.pkl", columns_cat)
